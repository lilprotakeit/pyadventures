# %%
import polars as pl

print("Polars version:", pl.__version__)
print("Requests successfully imported!")
# Out:
# Polars version: 1.41.2
# Requests successfully imported!

# %%
import cowsay

cowsay.cow("Hello Praveen! This is running natively on the M4 Pro.")
# Out:
#   _________________________________________________
#  /                                                 \
# | Hello Praveen! This is running natively on the M4 |
# |  Pro.                                             |
#  \                                                 /
# ...
#                                                  \
#                                                   \
#                                                     ^__^
#                                                     (oo)\_______
#                                                     (__)\       )\/\
#                                                         ||----w |
#                                                         ||     ||
